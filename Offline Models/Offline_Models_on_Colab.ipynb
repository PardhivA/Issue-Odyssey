# %% [markdown]
# # **CodeExplainer**

# %%
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    AutoConfig,
    pipeline,
)

model_name = "ashwinR/CodeExplainer"

tokenizer = AutoTokenizer.from_pretrained(model_name, padding=True)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

config = AutoConfig.from_pretrained(model_name)

model.eval()

pipe = pipeline("summarization", model=model_name, config=config, tokenizer=tokenizer)

raw_code = """
def fun(int arr[]){
  arr1 =[]
  for i in arr:
    if i % 2 != 0:
      arr1.append(i)
}
"""
print("\n\n")
print(pipe(raw_code)[0]["summary_text"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.51k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/511k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.37M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/15.5k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.50k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# Your max_length is set to 200, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# 1. Create a function fun that takes an int array and returns an array of integers.
# 2. Then it creates a list of integers that are even numbers.
# 3. Next step is to create an empty list.
# Create a function that takes in an integer arr as an argument.
#
# 1. Iterate through the int array arr and append all the integers in the array to the list arr1.
# 4. Then we iterate through the array and add all the numbers that are not odd.
# for i in arr, if i % 2 != 0, it appends the integer i to the arr1

# %% [markdown]
# ## Issue Issue Mapping Techniques
#
# 1. Methods Changed between issues
# 2. Methods diff summarization
# 3. Issue title and body matching

# %%
from transformers import RobertaTokenizer, T5ForConditionalGeneration

if __name__ == '__main__':
    tokenizer = RobertaTokenizer.from_pretrained('Salesforce/codet5-base')
    model = T5ForConditionalGeneration.from_pretrained('Salesforce/codet5-base-multi-sum')

    text = """def fun(a):
    if a % 2 == 1:
      return true
    else return false"""

    input_ids = tokenizer(text, return_tensors="pt").input_ids

    generated_ids = model.generate(input_ids, max_length=20)
    print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
    # this prints: "Convert a SVG string to a QImage."
# Out:
# Check if a is a non - zero non - zero non - zero non - zero non

# %%
# !pip install gsutil
# Out:
# Collecting gsutil
#   Downloading gsutil-5.27.tar.gz (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting argcomplete>=1.9.4 (from gsutil)
#   Downloading argcomplete-3.2.3-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.1 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from gsutil)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting fasteners>=0.14.1 (from gsutil)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Collecting gcs-oauth2-boto-plugin>=3.0 (from gsutil)
#   Downloading gcs-oauth2-boto-plugin-3.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting google-apitools>=0.5.32 (from gsutil)
#   Downloading google_apitools-0.5.32-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 14.9 MB/s eta 0:00:00
# Collecting httplib2==0.20.4 (from gsutil)
#   Downloading httplib2-0.20.4-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 11.9 MB/s eta 0:00:00
# Collecting google-reauth>=0.1.0 (from gsutil)
#   Downloading google_reauth-0.1.1-py2.py3-none-any.whl (17 kB)
# Collecting monotonic>=1.4 (from gsutil)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pyOpenSSL>=0.13 in /usr/local/lib/python3.10/dist-packages (from gsutil) (24.1.0)
# Collecting retry_decorator>=1.0.0 (from gsutil)
#   Downloading retry_decorator-1.1.1.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (1.16.0)
# Requirement already satisfied: google-auth[aiohttp]>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (2.27.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2==0.20.4->gsutil) (3.1.2)
# Collecting rsa==4.7.2 (from gcs-oauth2-boto-plugin>=3.0->gsutil)
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting boto>=2.29.1 (from gcs-oauth2-boto-plugin>=3.0->gsutil)
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.4 MB/s eta 0:00:00
# Requirement already satisfied: oauth2client>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil) (4.1.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa==4.7.2->gcs-oauth2-boto-plugin>=3.0->gsutil) (0.5.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (0.3.0)
# Requirement already satisfied: aiohttp<4.0.0.dev0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (3.9.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (2.31.0)
# Collecting pyu2f (from google-reauth>=0.1.0->gsutil)
#   Downloading pyu2f-0.1.5.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cryptography<43,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL>=0.13->gsutil) (42.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<43,>=41.0.5->pyOpenSSL>=0.13->gsutil) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (2024.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<43,>=41.0.5->pyOpenSSL>=0.13->gsutil) (2.21)
# Building wheels for collected packages: gsutil, crcmod, gcs-oauth2-boto-plugin, retry_decorator, pyu2f
#   Building wheel for gsutil (setup.py) ... done
#   Created wheel for gsutil: filename=gsutil-5.27-py3-none-any.whl size=3785292 sha256=7bd53f2db38112a5f1c18b52e5369528a6904870b9b82338bc4f3a205084377d
#   Stored in directory: /root/.cache/pip/wheels/03/0c/cd/24471307835689188d49827232a1430bdd36587f913d8f707f
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp310-cp310-linux_x86_64.whl size=31404 sha256=b0b298ad503e8ee82491531f7f91c611ca72e717d2313b6ef139653f3cc0f5ea
#   Stored in directory: /root/.cache/pip/wheels/85/4c/07/72215c529bd59d67e3dac29711d7aba1b692f543c808ba9e86
#   Building wheel for gcs-oauth2-boto-plugin (setup.py) ... done
#   Created wheel for gcs-oauth2-boto-plugin: filename=gcs_oauth2_boto_plugin-3.0-py3-none-any.whl size=23214 sha256=b67c79dffe43285142e2b5aa5eb2405d47316abe5eb58092c448be86b0334bf8
#   Stored in directory: /root/.cache/pip/wheels/77/2a/cd/c7b51b51563ebefe01488e3ecb19df401ea6725771937d3bc6
#   Building wheel for retry_decorator (setup.py) ... done
#   Created wheel for retry_decorator: filename=retry_decorator-1.1.1-py2.py3-none-any.whl size=3636 sha256=ec9b238291af8fb01a40cc3d7f678b9f3f7f78dc20574904889b2205dc2dc275
#   Stored in directory: /root/.cache/pip/wheels/dd/ac/77/8c54eac0d373d9eacfbe42599710c9bf91b4c5985297f6922a
#   Building wheel for pyu2f (setup.py) ... done
#   Created wheel for pyu2f: filename=pyu2f-0.1.5-py3-none-any.whl size=39402 sha256=4043217725121904125485c2b3e8d036ae2485f4d4787ab2755d3a6b0eb4ebb6
#   Stored in directory: /root/.cache/pip/wheels/ab/7b/27/66d7389916ad9e6caabb23cb55a4cf483dbbe5e6fc2a5cb428
# Successfully built gsutil crcmod gcs-oauth2-boto-plugin retry_decorator pyu2f
# Installing collected packages: retry_decorator, monotonic, crcmod, boto, rsa, pyu2f, httplib2, fasteners, argcomplete, google-reauth, google-apitools, gcs-oauth2-boto-plugin, gsutil
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: httplib2
#     Found existing installation: httplib2 0.22.0
#     Uninstalling httplib2-0.22.0:
#       Successfully uninstalled httplib2-0.22.0
# Successfully installed argcomplete-3.2.3 boto-2.49.0 crcmod-1.7 fasteners-0.19 gcs-oauth2-boto-plugin-3.0 google-apitools-0.5.32 google-reauth-0.1.1 gsutil-5.27 httplib2-0.20.4 monotonic-1.6 pyu2f-0.1.5 retry_decorator-1.1.1 rsa-4.7.2

# %%
# pip install gsutil
! git clone https://github.com/salesforce/CodeT5.git
# !cd your-cloned-codet5-path

# gsutil -m cp -r "gs://sfr-codet5-data-research/pretrained_models" .
# gsutil -m cp -r "gs://sfr-codet5-data-research/data" .
# gsutil -m cp -r "gs://sfr-codet5-data-research/finetuned_models" .
# Out:
# Cloning into 'CodeT5'...
# remote: Enumerating objects: 295, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 295 (delta 105), reused 66 (delta 66), pack-reused 155
# Receiving objects: 100% (295/295), 10.91 MiB | 11.03 MiB/s, done.
# Resolving deltas: 100% (151/151), done.

# %%
# !cd CodeT5/

# %%
# !cd CodeT5/
# !gsutil -m cp -r "gs://sfr-codet5-data-research/pretrained_models" .
# !gsutil -m cp -r "gs://sfr-codet5-data-research/data" .
# !gsutil -m cp -r "gs://sfr-codet5-data-research/finetuned_models" .
# Out:
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_base/config.json...
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_small/pytorch_model.bin...
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_small/config.json...
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_base/pytorch_model.bin...
# Copying gs://sfr-codet5-data-research/data/clone/data.jsonl...
# Copying gs://sfr-codet5-data-research/data/clone/test.txt...
# Copying gs://sfr-codet5-data-research/data/concode/test.json...
# Copying gs://sfr-codet5-data-research/data/concode/train.json...
# Copying gs://sfr-codet5-data-research/data/clone/valid.txt...
# Copying gs://sfr-codet5-data-research/data/clone/train.txt...
# Copying gs://sfr-codet5-data-research/data/defect/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/defect/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/concode/dev.json...
# Copying gs://sfr-codet5-data-research/data/defect/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/refine/medium/test.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/medium/test.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/medium/train.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/medium/train.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/medium/valid.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/medium/valid.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/small/test.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/small/test.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/small/train.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/small/train.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/small/valid.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/small/valid.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/summarize/go/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/go/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/go/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/java/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/java/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/java/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/javascript/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/javascript/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/javascript/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/php/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/php/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/php/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/python/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/python/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/python/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/ruby/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/ruby/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/ruby/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/translate/test.java-cs.txt.cs...
# Copying gs://sfr-codet5-data-research/data/translate/test.java-cs.txt.java...
# Copying gs://sfr-codet5-data-research/data/translate/train.java-cs.txt.cs...
# Copying gs://sfr-codet5-data-research/data/translate/train.java-cs.txt.java...
# Copying gs://sfr-codet5-data-research/data/translate/valid.java-cs.txt.cs...
# Copying gs://sfr-codet5-data-research/data/translate/valid.java-cs.txt.java...
# \ [46/46 files][  2.9 GiB/  2.9 GiB] 100% Done  72.6 MiB/s ETA 00:00:00
# Operation completed over 46 objects/2.9 GiB.
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_medium_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_medium_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/clone_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/concode_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_small_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/concode_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/defect_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_small_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_go_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_go_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_java_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_java_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_javascript_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_javascript_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_php_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_php_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_python_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_python_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_ruby_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_ruby_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_cs_java_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_cs_java_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_java_cs_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_java_cs_codet5_large.bin...

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 54.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 69.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 80.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 54.3 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.28.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105

# %% [markdown]
# # **falcon-7b-instruct**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)
sequences = pipeline(
   "Girafatron is obsessed with giraffes, the most glorious animal on the face of this Earth. Giraftron believes all other animals are irrelevant when compared to the glorious majesty of the giraffe.\nDaniel: Hello, Girafatron!\nGirafatron:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.tiiuae.falcon-7b-instruct.cf4b3c42ce2fdfe24f753f0f0d179202fea59c99.configuration_falcon:
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# modeling_falcon.py:   0%|          | 0.00/56.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-7ad604bf0ceb> in <cell line: 8>()
#       6
#       7 tokenizer = AutoTokenizer.from_pretrained(model)
# ----> 8 pipeline = transformers.pipeline(
#       9     "text-generation",
#      10     model=model,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     903     if isinstance(model, str) or framework is None:
#     904         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 905         framework, model = infer_framework_load_model(
#     906             model,
#     907             model_classes=model_classes,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     277
#     278             try:
# --> 279                 model = model_class.from_pretrained(model, **kwargs)
#     280                 if hasattr(model, "eval"):
#     281                     model = model.eval()
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     554             else:
#     555                 cls.register(config.__class__, model_class, exist_ok=True)
# --> 556             return model_class.from_pretrained(
#     557                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     558             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2943                 )
#    2944             elif not is_accelerate_available():
# -> 2945                 raise ImportError(
#    2946                     "Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`"
#    2947                 )
#
# ImportError: Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install gsutil
! git clone https://github.com/salesforce/CodeT5.git
# !cd CodeT5/
# !gsutil -m cp -r "gs://sfr-codet5-data-research/pretrained_models" .
# !gsutil -m cp -r "gs://sfr-codet5-data-research/data" .
# !gsutil -m cp -r "gs://sfr-codet5-data-research/finetuned_models" .
# !pip install accelerate
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
)
sequences = pipeline(
   "Girafatron is obsessed with giraffes, the most glorious animal on the face of this Earth. Giraftron believes all other animals are irrelevant when compared to the glorious majesty of the giraffe.\nDaniel: Hello, Girafatron!\nGirafatron:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Requirement already satisfied: gsutil in /usr/local/lib/python3.10/dist-packages (5.27)
# Requirement already satisfied: argcomplete>=1.9.4 in /usr/local/lib/python3.10/dist-packages (from gsutil) (3.2.3)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.10/dist-packages (from gsutil) (1.7)
# Requirement already satisfied: fasteners>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from gsutil) (0.19)
# Requirement already satisfied: gcs-oauth2-boto-plugin>=3.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (3.0)
# Requirement already satisfied: google-apitools>=0.5.32 in /usr/local/lib/python3.10/dist-packages (from gsutil) (0.5.32)
# Requirement already satisfied: httplib2==0.20.4 in /usr/local/lib/python3.10/dist-packages (from gsutil) (0.20.4)
# Requirement already satisfied: google-reauth>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (0.1.1)
# Requirement already satisfied: monotonic>=1.4 in /usr/local/lib/python3.10/dist-packages (from gsutil) (1.6)
# Requirement already satisfied: pyOpenSSL>=0.13 in /usr/local/lib/python3.10/dist-packages (from gsutil) (24.1.0)
# Requirement already satisfied: retry-decorator>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (1.1.1)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (1.16.0)
# Requirement already satisfied: google-auth[aiohttp]>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from gsutil) (2.27.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2==0.20.4->gsutil) (3.1.2)
# Requirement already satisfied: rsa==4.7.2 in /usr/local/lib/python3.10/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil) (4.7.2)
# Requirement already satisfied: boto>=2.29.1 in /usr/local/lib/python3.10/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil) (2.49.0)
# Requirement already satisfied: oauth2client>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from gcs-oauth2-boto-plugin>=3.0->gsutil) (4.1.3)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa==4.7.2->gcs-oauth2-boto-plugin>=3.0->gsutil) (0.5.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (0.3.0)
# Requirement already satisfied: aiohttp<4.0.0.dev0,>=3.6.2 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (3.9.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.20.0 in /usr/local/lib/python3.10/dist-packages (from google-auth[aiohttp]>=2.5.0->gsutil) (2.31.0)
# Requirement already satisfied: pyu2f in /usr/local/lib/python3.10/dist-packages (from google-reauth>=0.1.0->gsutil) (0.1.5)
# Requirement already satisfied: cryptography<43,>=41.0.5 in /usr/local/lib/python3.10/dist-packages (from pyOpenSSL>=0.13->gsutil) (42.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0.dev0,>=3.6.2->google-auth[aiohttp]>=2.5.0->gsutil) (4.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<43,>=41.0.5->pyOpenSSL>=0.13->gsutil) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.20.0->google-auth[aiohttp]>=2.5.0->gsutil) (2024.2.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<43,>=41.0.5->pyOpenSSL>=0.13->gsutil) (2.21)
# fatal: destination path 'CodeT5' already exists and is not an empty directory.
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_small/config.json...
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_base/config.json...
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_base/pytorch_model.bin...
# Copying gs://sfr-codet5-data-research/pretrained_models/codet5_small/pytorch_model.bin...
# Resuming download for ./pretrained_models/codet5_base/pytorch_model.bin component 0
# Resuming download for ./pretrained_models/codet5_base/pytorch_model.bin component 2
# Resuming download for ./pretrained_models/codet5_base/pytorch_model.bin component 1
# Download already complete for ./pretrained_models/codet5_base/pytorch_model.bin component 3, skipping download but will run integrity checks.
# Copying gs://sfr-codet5-data-research/data/concode/test.json...
# Copying gs://sfr-codet5-data-research/data/clone/test.txt...
# Copying gs://sfr-codet5-data-research/data/concode/train.json...
# Copying gs://sfr-codet5-data-research/data/clone/data.jsonl...
# Copying gs://sfr-codet5-data-research/data/clone/train.txt...
# Copying gs://sfr-codet5-data-research/data/clone/valid.txt...
# Copying gs://sfr-codet5-data-research/data/defect/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/defect/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/concode/dev.json...
# Copying gs://sfr-codet5-data-research/data/defect/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/refine/medium/test.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/medium/test.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/medium/train.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/medium/train.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/medium/valid.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/medium/valid.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/small/test.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/small/test.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/small/train.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/small/train.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/refine/small/valid.buggy-fixed.buggy...
# Copying gs://sfr-codet5-data-research/data/refine/small/valid.buggy-fixed.fixed...
# Copying gs://sfr-codet5-data-research/data/summarize/go/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/go/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/go/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/java/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/java/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/java/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/javascript/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/javascript/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/javascript/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/php/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/php/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/php/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/python/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/python/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/python/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/ruby/test.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/ruby/train.jsonl...
# Copying gs://sfr-codet5-data-research/data/summarize/ruby/valid.jsonl...
# Copying gs://sfr-codet5-data-research/data/translate/test.java-cs.txt.cs...
# Copying gs://sfr-codet5-data-research/data/translate/test.java-cs.txt.java...
# Copying gs://sfr-codet5-data-research/data/translate/train.java-cs.txt.cs...
# Copying gs://sfr-codet5-data-research/data/translate/train.java-cs.txt.java...
# Copying gs://sfr-codet5-data-research/data/translate/valid.java-cs.txt.cs...
# Copying gs://sfr-codet5-data-research/data/translate/valid.java-cs.txt.java...
# \ [46/46 files][  2.9 GiB/  2.9 GiB] 100% Done  70.4 MiB/s ETA 00:00:00
# Operation completed over 46 objects/2.9 GiB.
# Copying gs://sfr-codet5-data-research/finetuned_models/concode_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/concode_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_small_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/clone_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/defect_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_medium_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_go_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_small_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/refine_medium_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_go_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_java_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_java_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_javascript_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_javascript_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_php_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_php_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_python_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_python_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_ruby_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/summarize_ruby_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_cs_java_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_cs_java_codet5_large.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_java_cs_codet5_base.bin...
# Copying gs://sfr-codet5-data-research/finetuned_models/translate_java_cs_codet5_large.bin...
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 59.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 75.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.7 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.3 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.28.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# configuration_falcon.py:   0%|          | 0.00/7.16k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - configuration_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.tiiuae.falcon-7b-instruct.cf4b3c42ce2fdfe24f753f0f0d179202fea59c99.configuration_falcon:
# WARNING: You are currently loading Falcon using legacy code contained in the model repository. Falcon has now been fully ported into the Hugging Face transformers library. For the most up-to-date and high-performance version of the Falcon model code, please update to the latest version of transformers and then load the model without the trust_remote_code=True argument.
# modeling_falcon.py:   0%|          | 0.00/56.9k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/tiiuae/falcon-7b-instruct:
# - modeling_falcon.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-b66094a5224c> in <cell line: 15>()
#      13
#      14 tokenizer = AutoTokenizer.from_pretrained(model)
# ---> 15 pipeline = transformers.pipeline(
#      16     "text-generation",
#      17     model=model,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     903     if isinstance(model, str) or framework is None:
#     904         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 905         framework, model = infer_framework_load_model(
#     906             model,
#     907             model_classes=model_classes,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     290             for class_name, trace in all_traceback.items():
#     291                 error += f"while loading with {class_name}, an error is thrown:\n{trace}\n"
# --> 292             raise ValueError(
#     293                 f"Could not load model {model} with any of the following classes: {class_tuple}. See the original errors:\n\n{error}\n"
#     294             )
#
# ValueError: Could not load model tiiuae/falcon-7b-instruct with any of the following classes: (<class 'transformers.models.auto.modeling_auto.AutoModelForCausalLM'>, <class 'transformers.models.auto.modeling_tf_auto.TFAutoModelForCausalLM'>, <class 'transformers.models.falcon.modeling_falcon.FalconForCausalLM'>). See the original errors:
#
# while loading with AutoModelForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py", line 279, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py", line 556, in from_pretrained
#     return model_class.from_pretrained(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 3502, in from_pretrained
#     ) = cls._load_pretrained_model(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 3611, in _load_pretrained_model
#     raise ValueError(
# ValueError: The current `device_map` had weights offloaded to the disk. Please provide an `offload_folder` for them. Alternatively, make sure you have `safetensors` installed if the model you are using offers the weights in this format.
#
# while loading with TFAutoModelForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py", line 279, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py", line 564, in from_pretrained
#     raise ValueError(
# ValueError: Unrecognized configuration class <class 'transformers_modules.tiiuae.falcon-7b-instruct.cf4b3c42ce2fdfe24f753f0f0d179202fea59c99.configuration_falcon.FalconConfig'> for this kind of AutoModel: TFAutoModelForCausalLM.
# Model type should be one of BertConfig, CamembertConfig, CTRLConfig, GPT2Config, GPT2Config, GPTJConfig, OpenAIGPTConfig, OPTConfig, RemBertConfig, RobertaConfig, RobertaPreLayerNormConfig, RoFormerConfig, TransfoXLConfig, XGLMConfig, XLMConfig, XLMRobertaConfig, XLNetConfig.
#
# while loading with FalconForCausalLM, an error is thrown:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py", line 279, in infer_framework_load_model
#     model = model_class.from_pretrained(model, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 3502, in from_pretrained
#     ) = cls._load_pretrained_model(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py", line 3611, in _load_pretrained_model
#     raise ValueError(
# ValueError: The current `device_map` had weights offloaded to the disk. Please provide an `offload_folder` for them. Alternatively, make sure you have `safetensors` installed if the model you are using offers the weights in this format.

# %% [markdown]
# # Ollama

# %%
# !pip install ollama
# Out:
# Requirement already satisfied: ollama in /usr/local/lib/python3.10/dist-packages (0.1.8)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from ollama) (0.27.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama) (1.2.0)

# %%
import ollama
response = ollama.chat(model='llama2', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      68     try:
# ---> 69         yield
#      70     except Exception as exc:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     232         with map_httpcore_exceptions():
# --> 233             resp = self._pool.handle_request(req)
#     234
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     215             self._close_connections(closing)
# --> 216             raise exc from None
#     217
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     195                     # Send the request on the assigned connection.
# --> 196                     response = connection.handle_request(
#     197                         pool_request.request
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      98             self._connect_failed = True
# ---> 99             raise exc
#     100
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#      75                 if self._connection is None:
# ---> 76                     stream = self._connect(request)
#      77
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_sync/connection.py in _connect(self, request)
#     121                     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 122                         stream = self._network_backend.connect_tcp(**kwargs)
#     123                         trace.return_value = stream
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_backends/sync.py in connect_tcp(self, host, port, timeout, local_address, socket_options)
#     204
# --> 205         with map_exceptions(exc_map):
#     206             sock = socket.create_connection(
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#
# /usr/local/lib/python3.10/dist-packages/httpcore/_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# <ipython-input-6-b89d430d91b5> in <cell line: 2>()
#       1 import ollama
# ----> 2 response = ollama.chat(model='llama2', messages=[
#       3   {
#       4     'role': 'user',
#       5     'content': 'Why is the sky blue?',
#
# /usr/local/lib/python3.10/dist-packages/ollama/_client.py in chat(self, model, messages, stream, format, options, keep_alive)
#     175         message['images'] = [_encode_image(image) for image in images]
#     176
# --> 177     return self._request_stream(
#     178       'POST',
#     179       '/api/chat',
#
# /usr/local/lib/python3.10/dist-packages/ollama/_client.py in _request_stream(self, stream, *args, **kwargs)
#      95     **kwargs,
#      96   ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 97     return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#      98
#      99   def generate(
#
# /usr/local/lib/python3.10/dist-packages/ollama/_client.py in _request(self, method, url, **kwargs)
#      66
#      67   def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 68     response = self._client.request(method, url, **kwargs)
#      69
#      70     try:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     825             extensions=extensions,
#     826         )
# --> 827         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     828
#     829     @contextmanager
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.10/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1013
#    1014         with request_context(request=request):
# -> 1015             response = transport.handle_request(request)
#    1016
#    1017         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     230             extensions=request.extensions,
#     231         )
# --> 232         with map_httpcore_exceptions():
#     233             resp = self._pool.handle_request(req)
#     234
#
# /usr/lib/python3.10/contextlib.py in __exit__(self, typ, value, traceback)
#     151                 value = typ()
#     152             try:
# --> 153                 self.gen.throw(typ, value, traceback)
#     154             except StopIteration as exc:
#     155                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.10/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#      84
#      85         message = str(exc)
# ---> 86         raise mapped_exc(message) from exc
#      87
#      88
#
# ConnectError: [Errno 111] Connection refused

# %% [markdown]
# # Bloom

# %%
# !pip install transformers -q

# %%
# !nvidia-smi
# Out:
# Tue Apr  2 14:18:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:696: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)

# %%
model_ID = "bigscience/bloom-7b1"

# %%
model = AutoModelForCausalLM.from_pretrained(model_ID, use_cache=False)
tokenizer = AutoTokenizer.from_pretrained(model_ID)
set_seed(2024)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/739 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/28.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.16G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-5-f7d2779b05b0> in <cell line: 1>()
# ----> 1 model = AutoModelForCausalLM.from_pretrained(model_ID, use_cache=False)
#       2 tokenizer = AutoTokenizer.from_pretrained(model_ID)
#       3 set_seed(2024)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     559         elif type(config) in cls._model_mapping.keys():
#     560             model_class = _get_model_class(config, cls._model_mapping)
# --> 561             return model_class.from_pretrained(
#     562                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     563             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3373         with ContextManagers(init_contexts):
#    3374             # Let's make sure we don't run the init function of buffer modules
# -> 3375             model = cls(config, *model_args, **model_kwargs)
#    3376
#    3377         # make sure we use the model's config since the __init__ call might have copied it
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bloom/modeling_bloom.py in __init__(self, config)
#     766     def __init__(self, config: BloomConfig):
#     767         super().__init__(config)
# --> 768         self.transformer = BloomModel(config)
#     769         self.lm_head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)
#     770
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bloom/modeling_bloom.py in __init__(self, config)
#     594
#     595         # Transformer blocks
# --> 596         self.h = nn.ModuleList([BloomBlock(config) for _ in range(config.num_hidden_layers)])
#     597
#     598         # Final Layer Norm
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bloom/modeling_bloom.py in <listcomp>(.0)
#     594
#     595         # Transformer blocks
# --> 596         self.h = nn.ModuleList([BloomBlock(config) for _ in range(config.num_hidden_layers)])
#     597
#     598         # Final Layer Norm
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bloom/modeling_bloom.py in __init__(self, config)
#     381         self.post_attention_layernorm = LayerNorm(hidden_size, eps=config.layer_norm_epsilon)
#     382
# --> 383         self.mlp = BloomMLP(config)
#     384
#     385         self.apply_residual_connection_post_layernorm = config.apply_residual_connection_post_layernorm
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bloom/modeling_bloom.py in __init__(self, config)
#     347         self.pretraining_tp = config.pretraining_tp
#     348         self.slow_but_exact = config.slow_but_exact
# --> 349         self.dense_h_to_4h = nn.Linear(hidden_size, 4 * hidden_size)
#     350         self.gelu_impl = BloomGelu()
#     351         self.dense_4h_to_h = nn.Linear(4 * hidden_size, hidden_size)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in __init__(self, in_features, out_features, bias, device, dtype)
#      96         self.in_features = in_features
#      97         self.out_features = out_features
# ---> 98         self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
#      99         if bias:
#     100             self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 256.00 MiB. GPU 0 has a total capacity of 14.75 GiB of which 51.06 MiB is free. Process 2161 has 14.70 GiB memory in use. Of the allocated memory 14.58 GiB is allocated by PyTorch, and 1024.00 KiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
story_title = 'An Unexpected Journey Through Time'
prompt = f'What is the first programming language ever invented ?.\n'

# %%
input_ids = tokenizer(prompt, return_tensors="pt").to(0)

sample = model.generate(**input_ids,
                        max_length=200, top_k=1,
                        temperature=0, repetition_penalty=2.0)

generated_story = tokenizer.decode(sample[0], skip_special_tokens=True)

# %%
import textwrap
wrapper = textwrap.TextWrapper(width=80)

# %%
formated_story = wrapper.fill(text=generated_story)
print(formated_story)
# Out:
# What is the first programming language ever invented ?. The answer is: Python.
# It was written by Guido van Rossum in 1973 and it has been around since then,
# but it’s not a popular choice for most people because of its complexity (it’s
# hard to learn) or lackluster performance on modern hardware. (It doesn’t have
# any built-in support yet.) Python can be used as an entry-level tool that you’ll
# use when you’re learning other languages like Java, .NET etc., so if that’s what
# your goal at this point would be: If there are no requirements beyond basic
# understanding how things work within their own environment – such as:

# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 26.4 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 37.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.28.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105

# %% [markdown]
# # **falcon-40b**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model = "tiiuae/falcon-40b"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto"
)
sequences = pipeline(
   "Girafatron is obsessed with giraffes, the most glorious animal on the face of this Earth. Giraftron believes all other animals are irrelevant when compared to the glorious majesty of the giraffe.\nDaniel: Hello, Girafatron!\nGirafatron:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-b20d99210e78> in <cell line: 8>()
#       6
#       7 tokenizer = AutoTokenizer.from_pretrained(model)
# ----> 8 pipeline = transformers.pipeline(
#       9     "text-generation",
#      10     model=model,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     903     if isinstance(model, str) or framework is None:
#     904         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 905         framework, model = infer_framework_load_model(
#     906             model,
#     907             model_classes=model_classes,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     277
#     278             try:
# --> 279                 model = model_class.from_pretrained(model, **kwargs)
#     280                 if hasattr(model, "eval"):
#     281                     model = model.eval()
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     554             else:
#     555                 cls.register(config.__class__, model_class, exist_ok=True)
# --> 556             return model_class.from_pretrained(
#     557                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     558             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2943                 )
#    2944             elif not is_accelerate_available():
# -> 2945                 raise ImportError(
#    2946                     "Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`"
#    2947                 )
#
# ImportError: Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")

input_text = '''You will receive two objects. One is the lines of code of a method before changes due to a commit and second one is also some lines of code of a method after changes, your job is to give me a one line summarization of what is altered and the meaning of it based on the before and after the method changes, only one line summarization. Before Changes: Line100: INSERT INTO `${tableName}_new` SELECT `id`, `repoID`, `name`, `imageURL`, `lang`,`enabled`,`installed`,`installedVersion`,`repositoryVersion`,0,`md5`,0 FROM `$tableName`
. After changes: Line100: INSERT INTO `${tableName}_new` SELECT `id`, `repoID`, `name`, `name`, `imageURL`, `lang`,`enabled`,`installed`,`installedVersion`,`repositoryVersion`,0,`md5`,0 FROM `$tableName`'''
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-95477884013e> in <cell line: 10>()
#       8 input_ids = tokenizer(input_text, return_tensors="pt")
#       9
# ---> 10 outputs = model.generate(**input_ids)
#      11 print(tokenizer.decode(outputs[0]))
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1464             self._setup_cache(cache_cls, max_batch_size=batch_size, max_cache_len=generation_config.max_length)
#    1465
# -> 1466         self._validate_generated_length(generation_config, input_ids_length, has_default_max_length)
#    1467
#    1468         # 7. determine generation mode
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _validate_generated_length(self, generation_config, input_ids_length, has_default_max_length)
#    1184         if input_ids_length >= generation_config.max_length:
#    1185             input_ids_string = "decoder_input_ids" if self.config.is_encoder_decoder else "input_ids"
# -> 1186             raise ValueError(
#    1187                 f"Input length of {input_ids_string} is {input_ids_length}, but `max_length` is set to"
#    1188                 f" {generation_config.max_length}. This can lead to unexpected behavior. You should consider"
#
# ValueError: Input length of input_ids is 187, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
input_text = '''What does this function do ?
fun(a,b):
  return a + b
'''
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-abb6f2cc6be1> in <cell line: 7>()
#       5 input_ids = tokenizer(input_text, return_tensors="pt")
#       6
# ----> 7 outputs = model.generate(**input_ids)
#       8 print(tokenizer.decode(outputs[0]))
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1464             self._setup_cache(cache_cls, max_batch_size=batch_size, max_cache_len=generation_config.max_length)
#    1465
# -> 1466         self._validate_generated_length(generation_config, input_ids_length, has_default_max_length)
#    1467
#    1468         # 7. determine generation mode
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _validate_generated_length(self, generation_config, input_ids_length, has_default_max_length)
#    1184         if input_ids_length >= generation_config.max_length:
#    1185             input_ids_string = "decoder_input_ids" if self.config.is_encoder_decoder else "input_ids"
# -> 1186             raise ValueError(
#    1187                 f"Input length of {input_ids_string} is {input_ids_length}, but `max_length` is set to"
#    1188                 f" {generation_config.max_length}. This can lead to unexpected behavior. You should consider"
#
# ValueError: Input length of input_ids is 22, but `max_length` is set to 20. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.

# %%
pip install accelerate

# %% [markdown]
# # **gemma-2b-it**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model_id = "google/gemma-2b-it"
dtype = torch.bfloat16

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="cuda",
    torch_dtype=dtype,
)

chat = [
    { "role": "user", "content": "Write a hello world program" },
]
prompt = tokenizer.apply_chat_template(chat, tokenize=False, add_generation_prompt=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-18-0ce17bde453a> in <cell line: 9>()
#       7
#       8 tokenizer = AutoTokenizer.from_pretrained(model_id)
# ----> 9 model = AutoModelForCausalLM.from_pretrained(
#      10     model_id,
#      11     device_map="cuda",
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     559         elif type(config) in cls._model_mapping.keys():
#     560             model_class = _get_model_class(config, cls._model_mapping)
# --> 561             return model_class.from_pretrained(
#     562                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     563             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2943                 )
#    2944             elif not is_accelerate_available():
# -> 2945                 raise ImportError(
#    2946                     "Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`"
#    2947                 )
#
# ImportError: Using `low_cpu_mem_usage=True` or a `device_map` requires Accelerate: `pip install accelerate`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("google/gemma-2b-it")
model = AutoModelForCausalLM.from_pretrained("google/gemma-2b-it")

input_text = "Write me a poem about Machine Learning."
input_ids = tokenizer(input_text, return_tensors="pt")

outputs = model.generate(**input_ids)
print(tokenizer.decode(outputs[0]))
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

device = "cuda" # the device to load the model onto

model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")

messages = [
    {"role": "user", "content": "What is your favourite condiment?"},
    {"role": "assistant", "content": "Well, I'm quite partial to a good squeeze of fresh lemon juice. It adds just the right amount of zesty flavour to whatever I'm cooking up in the kitchen!"},
    {"role": "user", "content": "Do you have mayonnaise recipes?"}
]

encodeds = tokenizer.apply_chat_template(messages, return_tensors="pt")

model_inputs = encodeds.to(device)
model.to(device)

generated_ids = model.generate(model_inputs, max_new_tokens=1000, do_sample=True)
decoded = tokenizer.batch_decode(generated_ids)
print(decoded[0])
