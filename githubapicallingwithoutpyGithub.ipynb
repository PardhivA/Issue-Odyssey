# %%
import requests
import json

# %%
GITHUB_AUTH_TOKEN = "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"
headers = {"Authorisation" : "token {}".format(GITHUB_AUTH_TOKEN)}
GITHUB_API_URL = "https://api.github.com/repos/shosetsuorg/shosetsu/issues"
# data=json.dumps(data)
data = {"state":"closed"}
# print(data)
# print(json.dumps(data))
r = requests.get(GITHUB_API_URL, params = data)
print(r)
output = json.loads(r.text)
index=  0
for obj in output:
    # pass
    print("serial no: " + str(index))
    index = index + 1
    print(obj["body"])
# Out:
# <Response [200]>
# serial no: 0
# None
# serial no: 1
# Before this fix extensions from external repos wouldnt restore properly so you would be left with broken backups.
#
# With this fix it fixes the big issue, but there are still a few issues. First it wont install extensions 100% of the time and therefor wont restore novels for it.
#
# I restored a few more times and it got everything eventually
# serial no: 2
# **Describe the bug**
# The app freezes and becomes unresponsive making me unable to scroll
#
# **To Reproduce**
# Steps to reproduce the behavior:
# 1. It becomes unresponsive
# 2. It freezes
# 3.  Crashes
#
# **Expected behavior**
# The app should not lag.
#
# **Screenshots**
# https://user-images.githubusercontent.com/109915412/184531627-ea3cf0ab-8186-4690-943e-e86ef26d040c.mp4
#
# **Device information:**
#  - OS: Android OS
#  - App Version: 2.0.0-2411
#
# **Additional context**
# @Doomsdayrs plz help
# serial no: 3
# ...

# %%
import requests

# GITHUB_AUTH_TOKEN = "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"  # Replace with your actual token
# headers = {"Authorization": "token {}".format(GITHUB_AUTH_TOKEN)}
GITHUB_API_URL = "https://api.github.com/repos/shosetsuorg/shosetsu/issues"

params = {"state": "closed"}  # Use query parameters for filtering

response = requests.get(GITHUB_API_URL,params=params)

if response.status_code == 200:
    output = response.json()
    for issue in output:
        print(issue["state"])  # Access the "state" field directly
else:
    print("Error:", response.status_code, response.text)  # Handle potential errors
# Out:
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
# closed
